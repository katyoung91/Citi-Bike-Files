# %%
#imports
import pandas as pd
from pathlib import Path

# %%
#import dfs
jan_df = pd.read_csv(Path("JC-202301-citibike-tripdata.csv"))
feb_df = pd.read_csv(Path("JC-202302-citibike-tripdata.csv"))
mar_df = pd.read_csv(Path("JC-202303-citibike-tripdata.csv"))
apr_df = pd.read_csv(Path("JC-202304-citibike-tripdata.csv"))
may_df = pd.read_csv(Path("JC-202305-citibike-tripdata.csv"))
jun_df = pd.read_csv(Path("JC-202306-citibike-tripdata.csv"))
jul_df = pd.read_csv(Path("JC-202307-citibike-tripdata.csv"))
aug_df = pd.read_csv(Path("JC-202308-citibike-tripdata.csv"))
sep_df = pd.read_csv(Path("JC-202309-citibike-tripdata.csv"))

# %%
#combine the dfs
combined_df = pd.concat([jan_df, feb_df, mar_df, apr_df, may_df, jun_df, jul_df, aug_df, sep_df])

combined_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
#save as a new CSV file

combined_df.to_csv(r"C:/Users/katyo/Documents/GW Bootcamp/Module_18_Assignment/combined_citibike_data.csv", index=False, header=True)
